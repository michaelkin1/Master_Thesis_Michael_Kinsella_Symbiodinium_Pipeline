# %%
import tifffile
import matplotlib.pyplot as plt
import numpy as np
import cv2

# Open the TIFF image file
with tifffile.TiffFile("C:/Users/micha/Desktop/Master_Project/tiff_file_converted.tiff") as tif:
    num_frames = len(tif.pages)
    print(f'Number of total frames: {num_frames}')  # Total number of frames in the tiff-file
    
    # Frame you want to display visually and metadata from 
    frame_to_display = 1
    
    tiff_data = tif.asarray(key=frame_to_display)#extract specific frame
  

    #Print metadata for the current frame
    print(f"Metadata for Frame {frame_to_display + 1} of {num_frames}")
    page = tif.pages[frame_to_display]
    for tag, value in page.tags.items():
        tag_name = str(tag)
        print(f"{tag_name}: {value}")
        
        
    print("-" * 50)  # Add a separator between frames
    # Display the chosen frame
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.imshow(tiff_data, cmap='gray')
    plt.title(f"Frame {frame_to_display + 1}")
    
    # Calculate and display the histogram
    plt.subplot(1, 2, 2)
    hist, bins = np.histogram(tiff_data.flatten(), bins=256, range=(0, 256))
    plt.plot(hist, color='gray', alpha=0.7)
    plt.xlabel('Pixel Intensity')
    plt.ylabel('Frequency')
    plt.title('Histogram of Pixel Intensities')
    plt.grid(True)
    
    plt.show()
    
    # Perform histogram equalization
    
    if tiff_data.shape[-1] == 3:
        tiff_data = cv2.cvtColor(tiff_data, cv2.COLOR_BGR2GRAY)

# Ensure the image is of the correct data type (CV_8UC1)
    if tiff_data.dtype != np.uint8:
        tiff_data = tiff_data.astype(np.uint8)
    
    
    equalized_image = cv2.equalizeHist(tiff_data)
    
        # Display the equalized image
    plt.figure(figsize=(16, 4))  # Adjust the width as needed
    plt.imshow(equalized_image, cmap='gray')
    plt.title(f"Equalized Frame {frame_to_display + 1}")

    # Calculate and display the equalized histogram
    plt.figure(figsize=(16, 4))
    plt.subplot(1, 3, 3)
    hist_eq, bins_eq = np.histogram(equalized_image.flatten(), bins=256, range=(0, 256))
    plt.plot(hist_eq, color='gray', alpha=0.7)
    plt.xlabel('Pixel Intensity')
    plt.ylabel('Frequency')
    plt.title('Equalized Histogram')
    plt.grid(True)

    plt.show()
# Out:
# Number of total frames: 392
# Metadata for Frame 2 of 392
# 256: TiffTag 256 ImageWidth @11094208 LONG8 @11094220 = 2560
# 257: TiffTag 257 ImageLength @11094228 LONG8 @11094240 = 2160
# 258: TiffTag 258 BitsPerSample @11094248 SHORT @11094260 = 16
# 259: TiffTag 259 Compression @11094268 SHORT @11094280 = NONE
# 262: TiffTag 262 PhotometricInterpretation @11094288 SHORT @11094300 = MINISBLACK
# 270: TiffTag 270 ImageDescription @11094308 ASCII[66] @11094536 = ImageJ= hyperstack
# 273: TiffTag 273 StripOffsets @11094328 LONG8[2160] @11094602 = (11129184, 11134304,
# 277: TiffTag 277 SamplesPerPixel @11094348 SHORT @11094360 = 1
# 278: TiffTag 278 RowsPerStrip @11094368 LONG8 @11094380 = 1
# 279: TiffTag 279 StripByteCounts @11094388 LONG8[2160] @11111882 = (5120, 5120, 5120
# 282: TiffTag 282 XResolution @11094408 RATIONAL @11094420 = (61538461, 1000)
# 283: TiffTag 283 YResolution @11094428 RATIONAL @11094440 = (61538461, 1000)
# 284: TiffTag 284 PlanarConfiguration @11094448 SHORT @11094460 = CONTIG
# 296: TiffTag 296 ResolutionUnit @11094468 SHORT @11094480 = CENTIMETER
# 305: TiffTag 305 Software @11094488 ASCII[22] @11129162 = OME Bio-Formats 7.0.1
# 339: TiffTag 339 SampleFormat @11094508 SHORT @11094520 = UINT
# --------------------------------------------------

# %%
#convert image to array

#img_array = np.asarray(img)
